# %% [markdown]
# CS210 - Introduction to Data Science
# Individual Project

# %%
#Below needed modules are imported
# !pip install reverse_geocoder
import pandas as pd 
import reverse_geocoder as rg
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns  # a visualization library based on matplotlib
import warnings
warnings.filterwarnings('ignore')

sns.set(style="darkgrid")
# Out:
# Requirement already satisfied: reverse_geocoder in c:\users\removevirus\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\removevirus\anaconda3\lib\site-packages (from reverse_geocoder) (1.14.3+mkl)
# Requirement already satisfied: scipy>=0.17.1 in c:\users\removevirus\anaconda3\lib\site-packages (from reverse_geocoder) (1.1.0)

# %%
data=pd.read_csv("taxi-trips.csv") #Data that is used is shown below

# %% [markdown]
# Task1
#
# Give basic information regarding the dataset such as shape, data types and descriptive statistics that
# summarize columns

# %%
data.shape 

#As we can see our data consist of  118185 row and 11 features
# Out:
# (118185, 11)

# %%
data.dtypes
# Out:
# id                     object
# vendor_id               int64
# pickup_datetime        object
# dropoff_datetime       object
# passenger_count         int64
# pickup_longitude      float64
# pickup_latitude       float64
# dropoff_longitude     float64
# dropoff_latitude      float64
# store_and_fwd_flag     object
# trip_duration           int64
# dtype: object

# %%
data.describe()
# Out:
#            vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  118185.000000    118185.000000     118185.000000    118185.000000
# mean        1.534958         1.657148        -73.973971        40.751392
# std         0.498779         1.313844          0.040456         0.027958
# min         1.000000         0.000000        -79.487900        40.225803
# 25%         1.000000         1.000000        -73.991875        40.737835
# 50%         2.000000         1.000000        -73.981796        40.754501
# 75%         2.000000         2.000000        -73.967575        40.768471
# max         2.000000         6.000000        -73.425018        41.292198
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count      118185.000000     118185.000000  118185.000000
# mean          -73.973538         40.752212     927.186310
# std             0.039192          0.032284    3118.710246
# min           -79.487900         40.225800       1.000000
# 25%           -73.991394         40.736462     393.000000
# 50%           -73.979759         40.754848     652.000000
# 75%           -73.962990         40.770077    1048.000000
# max           -73.055977         41.292198   86366.000000

# %% [markdown]
# Task2
#
# Create two new columns named ”pickup district” and ”dropoff district” by applying reverse geocoding 1 2 to associated coordinates.

# %%
# Creation of latitude and longitude is shown below

a=list(zip(data["pickup_latitude"], data["pickup_longitude"]))

b= list(zip(data["dropoff_latitude"], data["dropoff_longitude"]))

# %%
#Reverse geocoder is applied according to the determined latitude and longitude
pickup_loc = rg.search(a)
dropoff_loc = rg.search(b)
# Out:
# Loading formatted geocoded file...

# %%
#districts of the pickups and droppffs are determind

Pickup_district= []
for i in pickup_loc:
    Pickup_district.append(i["name"])
Dropoff_district= []
for j in dropoff_loc:
    Dropoff_district.append(j["name"])

data['Pickup_district'] = Pickup_district
data['Dropoff_district'] = Dropoff_district
data.head(10)
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id0012891          2  2016-03-10 21:45:01  2016-03-10 22:05:26
# 2  id3361153          1  2016-03-11 07:11:23  2016-03-11 07:20:09
# 3  id2129090          1  2016-03-14 14:05:39  2016-03-14 14:28:05
# 4  id0256505          1  2016-03-14 15:04:38  2016-03-14 15:16:13
# 5  id0970832          1  2016-03-12 20:39:39  2016-03-12 21:05:40
# 6  id2049424          2  2016-03-02 20:15:07  2016-03-02 20:37:43
# 7  id0038484          2  2016-03-09 13:41:11  2016-03-09 13:53:27
# 8  id3092788          2  2016-03-03 22:01:32  2016-03-03 22:17:44
# 9  id3863815          2  2016-03-14 04:24:36  2016-03-14 04:37:11
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.981049        40.744339         -73.973000
# 2                1        -73.994560        40.750526         -73.978500
# 3                1        -73.975090        40.758766         -73.953201
# 4                1        -73.994484        40.745087         -73.998993
# 5                1        -74.008247        40.747353         -73.979446
# 6                1        -73.963890        40.773651         -74.005112
# 7                2        -73.972855        40.764400         -73.971809
# 8                2        -73.984772        40.710571         -73.989410
# 9                3        -73.944359        40.714489         -73.910530
#
#    dropoff_latitude store_and_fwd_flag  trip_duration   Pickup_district  \
# 0         40.765602                  N            455         Manhattan
# 1         40.789989                  N           1225  Long Island City
# 2         40.756191                  N            526         Weehawken
# 3         40.765068                  N           1346         Manhattan
# 4         40.722710                  N            695     New York City
# 5         40.718750                  N           1561           Hoboken
# 6         40.751492                  N           1356         Manhattan
# 7         40.757889                  N            736         Manhattan
# 8         40.730148                  N            972     New York City
# 9         40.709492                  N            755  Long Island City
#
#    Dropoff_district
# 0         Manhattan
# 1         Manhattan
# 2         Manhattan
# 3  Long Island City
# 4     New York City
# 5     New York City
# 6         Weehawken
# 7         Manhattan
# 8     New York City
# 9     East New York

# %%
#New columns are shown as  Pickup_district and Dropoff_district

# %% [markdown]
# Task 3
#
# Extract the top 5 districts where passengers prefer to leave and arrive.

# %%
#For leave

df_top_freq = data.groupby(['Pickup_district']).count().sort_values("vendor_id", ascending=False)
df_top_freq["id"][:5]
# Out:
# Pickup_district
# Manhattan           45329
# New York City       34625
# Long Island City    17787
# Weehawken           11334
# The Bronx            2777
# Name: id, dtype: int64

# %%
#For leave

# %%
df_top_drop = data.groupby(['Dropoff_district']).count().sort_values("id", ascending=False)
df_top_drop["id"][:5]
# Out:
# Dropoff_district
# Manhattan           44478
# New York City       31082
# Long Island City    19919
# Weehawken           10621
# Brooklyn             2059
# Name: id, dtype: int64

# %% [markdown]
# Task 4
# Create a new column named ”distance” by utilizing pick up and drop off coordinates 3

# %%
#Task4 is shown below 

a=list(zip(data["pickup_latitude"], data["pickup_longitude"]))

b= list(zip(data["dropoff_latitude"], data["dropoff_longitude"]))

import geopy
from geopy.distance import *

distance=[]
for i in range(0,len(a)):
    distance.append(geodesic(a[i],b[i]).miles)
data["Distance"]=distance

# %%
data.head(10)
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id0012891          2  2016-03-10 21:45:01  2016-03-10 22:05:26
# 2  id3361153          1  2016-03-11 07:11:23  2016-03-11 07:20:09
# 3  id2129090          1  2016-03-14 14:05:39  2016-03-14 14:28:05
# 4  id0256505          1  2016-03-14 15:04:38  2016-03-14 15:16:13
# 5  id0970832          1  2016-03-12 20:39:39  2016-03-12 21:05:40
# 6  id2049424          2  2016-03-02 20:15:07  2016-03-02 20:37:43
# 7  id0038484          2  2016-03-09 13:41:11  2016-03-09 13:53:27
# 8  id3092788          2  2016-03-03 22:01:32  2016-03-03 22:17:44
# 9  id3863815          2  2016-03-14 04:24:36  2016-03-14 04:37:11
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.981049        40.744339         -73.973000
# 2                1        -73.994560        40.750526         -73.978500
# 3                1        -73.975090        40.758766         -73.953201
# 4                1        -73.994484        40.745087         -73.998993
# 5                1        -74.008247        40.747353         -73.979446
# 6                1        -73.963890        40.773651         -74.005112
# 7                2        -73.972855        40.764400         -73.971809
# 8                2        -73.984772        40.710571         -73.989410
# 9                3        -73.944359        40.714489         -73.910530
#
#    dropoff_latitude store_and_fwd_flag  trip_duration   Pickup_district  \
# 0         40.765602                  N            455         Manhattan
# 1         40.789989                  N           1225  Long Island City
# 2         40.756191                  N            526         Weehawken
# 3         40.765068                  N           1346         Manhattan
# 4         40.722710                  N            695     New York City
# 5         40.718750                  N           1561           Hoboken
# 6         40.751492                  N           1356         Manhattan
# 7         40.757889                  N            736         Manhattan
# 8         40.730148                  N            972     New York City
# 9         40.709492                  N            755  Long Island City
#
#    Dropoff_district  Distance
# 0         Manhattan  0.933406
# 1         Manhattan  3.178194
# 2         Manhattan  0.928961
# 3  Long Island City  1.228003
# 4     New York City  1.562103
# 5     New York City  2.486098
# 6         Weehawken  2.648687
# 7         Manhattan  0.452659
# 8     New York City  1.372636
# 9     East New York  1.809375

# %% [markdown]
# TASK 5
#
# Create a new column named ”time of day” by aggregating timestamps in ”pickup datetime” into
# 5 different categories.

# %%
#Datetime is converted from Panda 

data["time_of_day"]=pd.to_datetime(data["pickup_datetime"])
data["pickup_datetime"]=pd.to_datetime(data["pickup_datetime"]) # i will use it in later part for finding day of week
data.head(10)
# Out:
#           id  vendor_id     pickup_datetime     dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id0012891          2 2016-03-10 21:45:01  2016-03-10 22:05:26
# 2  id3361153          1 2016-03-11 07:11:23  2016-03-11 07:20:09
# 3  id2129090          1 2016-03-14 14:05:39  2016-03-14 14:28:05
# 4  id0256505          1 2016-03-14 15:04:38  2016-03-14 15:16:13
# 5  id0970832          1 2016-03-12 20:39:39  2016-03-12 21:05:40
# 6  id2049424          2 2016-03-02 20:15:07  2016-03-02 20:37:43
# 7  id0038484          2 2016-03-09 13:41:11  2016-03-09 13:53:27
# 8  id3092788          2 2016-03-03 22:01:32  2016-03-03 22:17:44
# 9  id3863815          2 2016-03-14 04:24:36  2016-03-14 04:37:11
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.981049        40.744339         -73.973000
# 2                1        -73.994560        40.750526         -73.978500
# 3                1        -73.975090        40.758766         -73.953201
# 4                1        -73.994484        40.745087         -73.998993
# 5                1        -74.008247        40.747353         -73.979446
# 6                1        -73.963890        40.773651         -74.005112
# 7                2        -73.972855        40.764400         -73.971809
# 8                2        -73.984772        40.710571         -73.989410
# 9                3        -73.944359        40.714489         -73.910530
#
#    dropoff_latitude store_and_fwd_flag  trip_duration   Pickup_district  \
# 0         40.765602                  N            455         Manhattan
# 1         40.789989                  N           1225  Long Island City
# 2         40.756191                  N            526         Weehawken
# 3         40.765068                  N           1346         Manhattan
# 4         40.722710                  N            695     New York City
# 5         40.718750                  N           1561           Hoboken
# 6         40.751492                  N           1356         Manhattan
# 7         40.757889                  N            736         Manhattan
# 8         40.730148                  N            972     New York City
# 9         40.709492                  N            755  Long Island City
#
#    Dropoff_district  Distance         time_of_day
# 0         Manhattan  0.933406 2016-03-14 17:24:55
# 1         Manhattan  3.178194 2016-03-10 21:45:01
# 2         Manhattan  0.928961 2016-03-11 07:11:23
# 3  Long Island City  1.228003 2016-03-14 14:05:39
# 4     New York City  1.562103 2016-03-14 15:04:38
# 5     New York City  2.486098 2016-03-12 20:39:39
# 6         Weehawken  2.648687 2016-03-02 20:15:07
# 7         Manhattan  0.452659 2016-03-09 13:41:11
# 8     New York City  1.372636 2016-03-03 22:01:32
# 9     East New York  1.809375 2016-03-14 04:24:36

# %%
def aggregate(row):
    hour=row["time_of_day"].hour
    if  hour >= 7  and hour <9:
        row["time_of_day"]="rush hour morning"
    elif hour >=9 and hour <16:
        row["time_of_day"]="afternoon"
    elif hour >=16 and hour < 18:
        row["time_of_day"]="rush hour evening"
    elif hour >=18 and  hour <23:
        row["time_of_day"]="evening"
    else:
        row["time_of_day"]="late_night"
    return row

# %%
data=data.apply(aggregate,axis=1)
data.head(10)
# Out:
#           id  vendor_id     pickup_datetime     dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id0012891          2 2016-03-10 21:45:01  2016-03-10 22:05:26
# 2  id3361153          1 2016-03-11 07:11:23  2016-03-11 07:20:09
# 3  id2129090          1 2016-03-14 14:05:39  2016-03-14 14:28:05
# 4  id0256505          1 2016-03-14 15:04:38  2016-03-14 15:16:13
# 5  id0970832          1 2016-03-12 20:39:39  2016-03-12 21:05:40
# 6  id2049424          2 2016-03-02 20:15:07  2016-03-02 20:37:43
# 7  id0038484          2 2016-03-09 13:41:11  2016-03-09 13:53:27
# 8  id3092788          2 2016-03-03 22:01:32  2016-03-03 22:17:44
# 9  id3863815          2 2016-03-14 04:24:36  2016-03-14 04:37:11
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.981049        40.744339         -73.973000
# 2                1        -73.994560        40.750526         -73.978500
# 3                1        -73.975090        40.758766         -73.953201
# 4                1        -73.994484        40.745087         -73.998993
# 5                1        -74.008247        40.747353         -73.979446
# 6                1        -73.963890        40.773651         -74.005112
# 7                2        -73.972855        40.764400         -73.971809
# 8                2        -73.984772        40.710571         -73.989410
# 9                3        -73.944359        40.714489         -73.910530
#
#    dropoff_latitude store_and_fwd_flag  trip_duration   Pickup_district  \
# 0         40.765602                  N            455         Manhattan
# 1         40.789989                  N           1225  Long Island City
# 2         40.756191                  N            526         Weehawken
# 3         40.765068                  N           1346         Manhattan
# 4         40.722710                  N            695     New York City
# 5         40.718750                  N           1561           Hoboken
# 6         40.751492                  N           1356         Manhattan
# 7         40.757889                  N            736         Manhattan
# 8         40.730148                  N            972     New York City
# 9         40.709492                  N            755  Long Island City
#
#    Dropoff_district  Distance        time_of_day
# 0         Manhattan  0.933406  rush hour evening
# 1         Manhattan  3.178194            evening
# 2         Manhattan  0.928961  rush hour morning
# 3  Long Island City  1.228003          afternoon
# 4     New York City  1.562103          afternoon
# 5     New York City  2.486098            evening
# 6         Weehawken  2.648687            evening
# 7         Manhattan  0.452659          afternoon
# 8     New York City  1.372636            evening
# 9     East New York  1.809375         late_night

# %% [markdown]
# Task 6
# • Show how the average distance varies as time of the day changes.

# %%
graph=data.groupby('time_of_day')["Distance"].mean()
plotting=graph.plot(kind='bar',legend=None)
plotting.set_xlabel("Time of Day")
plotting.set_ylabel("Distance")
plotting.set_title("Bar chart of Distance taken from passengers according to the Time of Day")
# Out:
# Text(0.5,1,'Bar chart of Distance taken from passengers according to the Time of Day')

# %% [markdown]
# Task 7
# Show how the trip duration varies as time of the day changes.

# %%
#Task 6 -b 

graph=data.groupby('time_of_day')["trip_duration"].mean()
plotting=graph.plot(kind='bar',legend=None)
plotting.set_xlabel("Time")
plotting.set_ylabel("Distance")
plotting.set_title("Bar chart of Trip duration of passengers according to the Time of Day")
# Out:
# Text(0.5,1,'Bar chart of Trip duration of passengers according to the Time of Day')

# %%
data['week_day'] = data['pickup_datetime'].dt.weekday_name
data.head(10)
# Out:
#           id  vendor_id     pickup_datetime     dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id0012891          2 2016-03-10 21:45:01  2016-03-10 22:05:26
# 2  id3361153          1 2016-03-11 07:11:23  2016-03-11 07:20:09
# 3  id2129090          1 2016-03-14 14:05:39  2016-03-14 14:28:05
# 4  id0256505          1 2016-03-14 15:04:38  2016-03-14 15:16:13
# 5  id0970832          1 2016-03-12 20:39:39  2016-03-12 21:05:40
# 6  id2049424          2 2016-03-02 20:15:07  2016-03-02 20:37:43
# 7  id0038484          2 2016-03-09 13:41:11  2016-03-09 13:53:27
# 8  id3092788          2 2016-03-03 22:01:32  2016-03-03 22:17:44
# 9  id3863815          2 2016-03-14 04:24:36  2016-03-14 04:37:11
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.981049        40.744339         -73.973000
# 2                1        -73.994560        40.750526         -73.978500
# 3                1        -73.975090        40.758766         -73.953201
# 4                1        -73.994484        40.745087         -73.998993
# 5                1        -74.008247        40.747353         -73.979446
# 6                1        -73.963890        40.773651         -74.005112
# 7                2        -73.972855        40.764400         -73.971809
# 8                2        -73.984772        40.710571         -73.989410
# 9                3        -73.944359        40.714489         -73.910530
#
#    dropoff_latitude store_and_fwd_flag  trip_duration   Pickup_district  \
# 0         40.765602                  N            455         Manhattan
# 1         40.789989                  N           1225  Long Island City
# 2         40.756191                  N            526         Weehawken
# 3         40.765068                  N           1346         Manhattan
# 4         40.722710                  N            695     New York City
# 5         40.718750                  N           1561           Hoboken
# 6         40.751492                  N           1356         Manhattan
# 7         40.757889                  N            736         Manhattan
# 8         40.730148                  N            972     New York City
# 9         40.709492                  N            755  Long Island City
#
#    Dropoff_district  Distance        time_of_day   week_day
# 0         Manhattan  0.933406  rush hour evening     Monday
# 1         Manhattan  3.178194            evening   Thursday
# 2         Manhattan  0.928961  rush hour morning     Friday
# 3  Long Island City  1.228003          afternoon     Monday
# 4     New York City  1.562103          afternoon     Monday
# 5     New York City  2.486098            evening   Saturday
# 6         Weehawken  2.648687            evening  Wednesday
# 7         Manhattan  0.452659          afternoon  Wednesday
# 8     New York City  1.372636            evening   Thursday
# 9     East New York  1.809375         late_night     Monday

# %%
#Hypothesis Testing
#1- Does passenger group size affect the distance?

# %%
from scipy import stats

sample1 = data[data['passenger_count']<2]['Distance']
sample2 = data[data['passenger_count']>=2]['Distance']
stats.ttest_ind(sample1, sample2, equal_var=False)  # since we have not equal variances
#Reject null hyp
# Out:
# Ttest_indResult(statistic=-4.903706114571113, pvalue=9.428588173218336e-07)

# %% [markdown]
# If we set the significance level as 0.05, we can reject the null hypothesis. In addition, the test score is negative which indicates that the mean score for  distance of passenger count < 2 is lower than those greater than and equal  2.

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,6))  # a figure with 1 row and 3 columns
                                              # ax variable stores a list with 3 elements
                                              # each element in ax correspons to chart
        
sample1.plot(kind="hist", ax=ax[0], bins=40, label="completed", color="c")
ax[0].set_title("Distance when passenger count <2 ")

sample2.plot(kind="hist", ax=ax[1], bins=40, label="none", color="m")
ax[1].set_title("Distance when passenger count >=2 ")

sns.kdeplot(sample1, shade=True, label=" None", ax=ax[2], color="c")
sns.kdeplot(sample2, shade=True, label=" None", ax=ax[2], color="m")
ax[2].set_title("Comparison with KDE")

plt.suptitle(" Distributions")
plt.show()

# %%
#2. Do trip distances increase in weekends?

# %%
from scipy import stats
s1=data.loc[data["week_day"].isin(['Saturday','Sunday'])]["Distance"]
s2=data.loc[data["week_day"].isin(['Monday','Tuesday','Wednesday','Thursday','Friday'])]["Distance"]
stats.ttest_ind(s1, s2, equal_var=False)  # since we have not equal variances
#Reject null hyp
# Out:
# Ttest_indResult(statistic=5.604877366928616, pvalue=2.0924144330692153e-08)

# %% [markdown]
# If we set the significance level as 0.05, we can reject the null hypothesis. In addition, the test score is negative which indicates that the mean score for distance in weekend  is lower than weekdays.

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,6))  # a figure with 1 row and 3 columns
                                              # ax variable stores a list with 3 elements
                                              # each element in ax correspons to chart
        
s1.plot(kind="hist", ax=ax[0], bins=40, label="completed", color="c")
ax[0].set_title("Distance took in weekdays")

s2.plot(kind="hist", ax=ax[1], bins=40, label="none", color="m")
ax[1].set_title("Distance took in weekend")

sns.kdeplot(s1, shade=True, label=" None", ax=ax[2], color="c")
sns.kdeplot(s2, shade=True, label=" None", ax=ax[2], color="m")
ax[2].set_title("Comparison with KDE")

plt.suptitle(" Distributions")
plt.show()
